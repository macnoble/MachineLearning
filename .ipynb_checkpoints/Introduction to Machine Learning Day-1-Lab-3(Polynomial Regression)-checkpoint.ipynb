# %%
import os

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 33, 34, 35]
    remove_indices = []
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction' , 'Household net adjusted disposable income']].iloc[keep_indices]
    #return full_country_stats

# %%
datapath = os.path.join("datasets", "lifesat", "")

# %%
import urllib.request
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
os.makedirs(datapath, exist_ok=True)
for filename in ("oecd_bli_2015.csv", "gdp_per_capita.csv"):
    print("Downloading", filename)
    url = DOWNLOAD_ROOT + "datasets/lifesat/" + filename
    urllib.request.urlretrieve(url, datapath + filename)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import sklearn.linear_model
 
# # Load the data
# oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
# gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
#                              encoding='latin1', na_values="n/a")
 
# # Prepare the data
# country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)

# #X = np.c_[country_stats["GDP per capita"]]
# #y = np.c_[country_stats["Life satisfaction"]]
# print(country_stats)
# Out:
#                  Air pollution  Assault rate  Consultation on rule-making  \
# Country
# Brazil                    18.0           7.9                          4.0
# Mexico                    30.0          12.8                          9.0
# Russia                    15.0           3.8                          2.5
# Turkey                    35.0           5.0                          5.5
# Hungary                   15.0           3.6                          7.9
# Poland                    33.0           1.4                         10.8
# Chile                     46.0           6.9                          2.0
# Slovak Republic           13.0           3.0                          6.6
# Czech Republic            16.0           2.8                          6.8
# Estonia                    9.0           5.5                          3.3
# Greece                    27.0           3.7                          6.5
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model
 
# Load the data
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
 
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)

X =  np.c_[country_stats["GDP per capita"]]
X1 = np.c_[country_stats["Household net adjusted disposable income"]]
y =  np.c_[country_stats["Life satisfaction"]]

print(country_stats)
# Out:
#                  GDP per capita  Life satisfaction  \
# Country
# Brazil                 8669.998                7.0
# Mexico                 9009.280                6.7
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Chile                 13340.905                6.7
# Slovak Republic       15991.736                6.1
# Czech Republic        17256.918                6.5
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# ...

# %%
# Visualize the data
#country_stats.plot(kind='scatter', x='GDP per capita' , y='Life satisfaction')

plt.scatter(X,y)         #x='GDP per capita' , y='Life satisfaction'
plt.scatter(X1,y)        #X='Household net adjusted disposable income ' , y='Life satisfaction'
plt.show()

# %%
# Select a linear model
model = sklearn.linear_model.LinearRegression()
 
# Train the model
model.fit(X, y)
 
# Make a prediction for Ghana
X_new = [[1784]]  # Ghana' GDP per capita
print(model.predict(X_new))

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

degree = 2
polyReg = make_pipeline(PolynomialFeatures(degree),sklearn.linear_model.LinearRegression())
polyReg.fit()

# %%
import sklearn.neighbors
model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)

# %%
model.fit(X,y)
X_new = [[1784]]  # Ghana' GDP per capita using KNearestNeighbors
print("Ghana's GDP per capita: ",model.predict(X_new))
# Out:
# Ghana's GDP per capita:  [[5.5]]

# %% [markdown]
# **Which approach(Linear Reagression vs K-Nearest Regression), do you think, would generally make a better prediction? Why?**
#
# As per IMF Ghana scores a value of 4.7. The linear regression used yielded a smaller error (4.940-4.7)= 0.204 as compared to the result from the K-Nearest Neighbors (4.7-5.5) = -0.8
#
# The problem is better approached usind a model-based approach as supposed to an instance-based approach. The method of estimation as employed by the KNN seems to be independent of the variable of interest and is based purely on the quanitative nature of the value under investigation.

# %% [markdown]
# Predicting life satisfaction based only on GDP per capita does not sound like something that could result in accurate predictions.
#
# 🗹 What arguments would you give to support it?
#
# GDP calculation does not take into account the standard of living of the citizens. The other players taken into account in calculating GDP as per the expenditure formula can skew the data.
#
# 🗹 What could we do to fix this?
#
# Assigning weights to the that are commensurate of the participating players in the calculating GDP can help in fixing it.
#
# Increasing the independent variables and ensuring these variables are correlated to the hypothesis (GDP is a measure of life satisfacetion)
